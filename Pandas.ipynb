# %%
# pip install pandas

# %% [markdown]
# ##  Pandas Series

# %%
import pandas as pd
import numpy as np

# %%
data=pd.Series([1,2,3])
data
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
myindex=['USA','CANO','Mex']
data=[112,321,321]
myser=pd.Series(data=data,index=myindex)
myser
# Out:
# USA     112
# CANO    321
# Mex     321
# dtype: int64

# %%
myser['USA']
# Out:
# np.int64(112)

# %%
age={'sam':2,'frank':90}
a=pd.Series(age)

# %%
a['sam']=0

# %%
a
# Out:
# sam       0
# frank    90
# dtype: int64

# %%
q1={'japan':80,'china':34,'india':32,'USA':80}
q2={'japan':90,'china':36,'india':33}

# %%
sales=pd.Series(q1)
sales
# Out:
# japan    80
# china    34
# india    32
# USA      80
# dtype: int64

# %%
sales1=pd.Series(q2)
sales1
# Out:
# japan    90
# china    36
# india    33
# dtype: int64

# %%
sales.get('japan')
# Out:
# np.int64(80)

# %%
sales.keys()
# Out:
# Index(['japan', 'china', 'india', 'USA'], dtype='object')

# %%
sales.values
# Out:
# array([80, 34, 32, 80])

# %%
[1,2]*2
# Out:
# [1, 2, 1, 2]

# %%
np.array([1,2])*2
# Out:
# array([2, 4])

# %%
sales*2
# Out:
# japan    160
# china     68
# india     64
# USA      160
# dtype: int64

# %%
sales+sales1
# Out:
# USA        NaN
# china     70.0
# india     65.0
# japan    170.0
# dtype: float64

# %%
sales.add(sales1,fill_value=0)
# Out:
# USA       80.0
# china     70.0
# india     65.0
# japan    170.0
# dtype: float64

# %%
sales.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## DataFrame

# %%
np.random.seed(101)
mydata=np.random.randint(0,101,(4,3))
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]], dtype=int32)

# %%
myindex=['CA','NY','Ew','Wq']
mycolumn=['Jan','Feb','Mar']

# %%
df=pd.DataFrame(mydata,columns=mycolumn,index=myindex)
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# Ew   75    9   77
# Wq   40    4   63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to Wq
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int32
#  1   Feb     4 non-null      int32
#  2   Mar     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %%
pwd
# Out:
# 'c:\\Work\\Python DataScience'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 2028-DBF2
#
#  Directory of c:\Work\Python DataScience
#
# 16-10-2024  08:33    <DIR>          .
# 13-10-2024  19:22    <DIR>          ..
# 13-10-2024  20:50                 5 .gitignore
# 13-10-2024  19:25    <DIR>          .venv
# 16-10-2024  08:33    <DIR>          Data
# 14-10-2024  12:15            24,119 Numpy.ipynb
# 19-10-2024  07:34           169,390 Pandas.ipynb
#                3 File(s)        193,514 bytes
#                4 Dir(s)  902,367,883,264 bytes free

# %%
df=pd.read_csv('.\\Data\\tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.shape
# Out:
# (244, 11)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.dtypes
# Out:
# total_bill          float64
# tip                 float64
# sex                  object
# smoker               object
# day                  object
# time                 object
# size                  int64
# price_per_person    float64
# Payer Name           object
# CC Number             int64
# Payment ID           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %% [markdown]
# - Information Based on Columns

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %%
mycol=['total_bill','tip']
df[mycol]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
np.round(23.9098098,2)
# Out:
# np.float64(23.91)

# %%
df['Tip_percentage']=np.round((df['tip']/df['total_bill']*100),2)

# %%
df['tip']/df['total_bill']*100
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Length: 244, dtype: float64

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  Tip_percentage
# ...

# %%
df.drop('Tip_percentage',axis=1,inplace=True)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# axis=0 --rows
# axis=1 --columns

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df=df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df=df.reset_index()

# %%
df.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %%
df=df.set_index("Payment ID")

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df.iloc[0:3]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322

# %%
df.loc[["Sun2959","Sun4458"]]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4458                 7.00      Travis Walters  6011812112971322

# %%
df.drop('Sun2959',axis=0,inplace=True)
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# Sun4458                 7.00    Travis Walters  6011812112971322
# Sun5260                11.84  Nathaniel Harris  4676137647685994
# Sun2251                 6.15      Tonya Carter  4832732618637221
# Sun9679                 6.32        Erik Smith   213140353657882

# %%
df.shape
# Out:
# (243, 10)

# %%
df.iloc[1:]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# Sun5985           8.77  2.00    Male     No   Sun  Dinner     2
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun4458                 7.00      Travis Walters  6011812112971322
# ...

# %%
one_row=df.iloc[0]
one_row
# Out:
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                3.45
# Payer Name            Douglas Tucker
# CC Number           4478071379779230
# Name: Sun4608, dtype: object

# %%
df=pd.concat([df,pd.DataFrame([one_row])],axis=0)

# %%
df.head()
# Out:
#          total_bill   tip     sex smoker  day    time  size  price_per_person  \
# Sun4608       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# Sun4458       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# Sun5260       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# Sun2251       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# Sun9679       25.29  4.71    Male     No  Sun  Dinner     4              6.32
#
#                Payer Name         CC Number
# Sun4608    Douglas Tucker  4478071379779230
# Sun4458    Travis Walters  6011812112971322
# Sun5260  Nathaniel Harris  4676137647685994
# Sun2251      Tonya Carter  4832732618637221
# Sun9679        Erik Smith   213140353657882

# %%
df.tail()
# Out:
#          total_bill   tip     sex smoker   day    time  size  \
# Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       18.78  3.00  Female     No  Thur  Dinner     2
# Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
#
#          price_per_person       Payer Name         CC Number
# Sat1766             13.59   Monica Sanders  3506806155565404
# Sat3880             11.34       Keith Wong  6011891618747196
# Sat17                8.91     Dennis Dixon     4375220550950
# Thur672              9.39  Michelle Hardin  3511451626698139
# Sun4608              3.45   Douglas Tucker  4478071379779230

# %%
df=pd.read_csv("./Data/tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
bool_seres=df['total_bill']>40
bool_seres
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill']>40]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 59       Brian Ortiz  6596453823950595    Sat8139
# ...

# %%
df[(df['sex']=='Male') & (df['size']==3)]
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 1         10.34   1.66  Male     No   Sun  Dinner     3              3.45
# 2         21.01   3.50  Male     No   Sun  Dinner     3              7.00
# 17        16.29   3.71  Male     No   Sun  Dinner     3              5.43
# 19        20.65   3.35  Male     No   Sat  Dinner     3              6.88
# 35        24.06   3.60  Male     No   Sat  Dinner     3              8.02
# 36        16.31   2.00  Male     No   Sat  Dinner     3              5.44
# 38        18.69   2.31  Male     No   Sat  Dinner     3              6.23
# 39        31.27   5.00  Male     No   Sat  Dinner     3             10.42
# 40        16.04   2.24  Male     No   Sat  Dinner     3              5.35
# 48        28.55   2.05  Male     No   Sun  Dinner     3              9.52
# 64        17.59   2.64  Male     No   Sat  Dinner     3              5.86
# 65        20.08   3.15  Male     No   Sat  Dinner     3              6.69
# ...

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df[(df['day']=='Sun') | (df['day']=='Fri')]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 222        8.58  1.92    Male    Yes  Fri   Lunch     1              8.58
# 223       15.98  3.00  Female     No  Fri   Lunch     3              5.33
# 224       13.42  1.58    Male    Yes  Fri   Lunch     2              6.71
# 225       16.27  2.50  Female    Yes  Fri   Lunch     2              8.14
# 226       10.09  2.00  Female    Yes  Fri   Lunch     2              5.04
#
#              Payer Name         CC Number Payment ID
# ...

# %%
options=['Sun','Fri']
df[df['day'].isin(options)]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 222        8.58  1.92    Male    Yes  Fri   Lunch     1              8.58
# 223       15.98  3.00  Female     No  Fri   Lunch     3              5.33
# 224       13.42  1.58    Male    Yes  Fri   Lunch     2              6.71
# 225       16.27  2.50  Female    Yes  Fri   Lunch     2              8.14
# 226       10.09  2.00  Female    Yes  Fri   Lunch     2              5.04
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ## Apply() -- used for single column applied function

# %%
import pandas as pd
import numpy as np
df=pd.read_csv(".//Data//tips.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
str(3560325168603410)[-4:]
# Out:
# '3410'

# %%
def last_four(num):
    return int(str(num)[-4:])
last_four('223456787654')
# Out:
# 7654

# %%
df['Lastfour']=df['CC Number'].apply(last_four)

# %%
df["total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
def yelp(price):
    if price<10:
        return '$'
    elif price>=10 and price<30:
        return '$$'
    else:
        return '$$$'

# %%
df['yelp']=df['total_bill'].apply(yelp)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  Lastfour yelp
# ...

# %%
df.iloc[1:2]
# Out:
#    total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 1       10.34  1.66  Male     No  Sun  Dinner     3              3.45
#
#        Payer Name         CC Number Payment ID  Lastfour yelp
# 1  Douglas Tucker  4478071379779230    Sun4608      9230   $$

# %%
df.loc[1:4]
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#          Payer Name         CC Number Payment ID  Lastfour yelp
# 1    Douglas Tucker  4478071379779230    Sun4608      9230   $$
# 2    Travis Walters  6011812112971322    Sun4458      1322   $$
# 3  Nathaniel Harris  4676137647685994    Sun5260      5994   $$
# 4      Tonya Carter  4832732618637221    Sun2251      7221   $$

# %%
df.loc[[1,2]]
# Out:
#    total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 1       10.34  1.66  Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50  Male     No  Sun  Dinner     3              7.00
#
#        Payer Name         CC Number Payment ID  Lastfour yelp
# 1  Douglas Tucker  4478071379779230    Sun4608      9230   $$
# 2  Travis Walters  6011812112971322    Sun4458      1322   $$

# %% [markdown]
# ## Lambda

# %%
num=8
print(lambda num:num*2)
# Out:
# <function <lambda> at 0x000001F8A57E1080>

# %%
df[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df[['total_bill','tip']].apply(lambda num :num*2)
# Out:
#      total_bill    tip
# 0         33.98   2.02
# 1         20.68   3.32
# 2         42.02   7.00
# 3         47.36   6.62
# 4         49.18   7.22
# ..          ...    ...
# 239       58.06  11.84
# 240       54.36   4.00
# 241       45.34   4.00
# 242       35.64   3.50
# 243       37.56   6.00
#
# [244 rows x 2 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  Lastfour yelp
# 0  Christy Cunningham  3560325168603410    Sun2959      3410   $$
# 1      Douglas Tucker  4478071379779230    Sun4608      9230   $$
# 2      Travis Walters  6011812112971322    Sun4458      1322   $$
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994   $$
# 4        Tonya Carter  4832732618637221    Sun2251      7221   $$

# %%
def quality(total_bill,tip):
    if tip/total_bill > 0.25:
        return "Generous"
    else:
        return "Other"

# %%
df['Quality']=df[['total_bill','tip']].apply(lambda df:quality(df['total_bill'],df['tip']),axis=1)

# %%
df['Quality']=np.vectorize(quality)(df['total_bill'],df['tip'])
df['Quality']
# Out:
# 0      Other
# 1      Other
# 2      Other
# 3      Other
# 4      Other
#        ...
# 239    Other
# 240    Other
# 241    Other
# 242    Other
# 243    Other
# Name: Quality, Length: 244, dtype: object

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  Lastfour yelp Quality
# 0  Christy Cunningham  3560325168603410    Sun2959      3410   $$   Other
# 1      Douglas Tucker  4478071379779230    Sun4608      9230   $$   Other
# 2      Travis Walters  6011812112971322    Sun4458      1322   $$   Other
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994   $$   Other
# 4        Tonya Carter  4832732618637221    Sun2251      7221   $$   Other

# %%
df['Quality'].value_counts()
# Out:
# Quality
# Other       234
# Generous     10
# Name: count, dtype: int64

# %%
import timeit 
  
# code snippet to be executed only once 
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('.//Data//tips.csv')
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"
'''
  
# code snippet whose execution time is to be measured 
stmt_one = ''' 
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_one, 
                    number = 1000)
# Out:
# 2.565880100009963

# %%
timeit.timeit(setup = setup, 
                    stmt = stmt_two, 
                    number = 1000)
# Out:
# 0.33688009998877533

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number  \
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15
#
#           Lastfour
# count   244.000000
# mean   4981.483607
# std    2956.069735
# min      11.000000
# 25%    2295.250000
# 50%    5142.000000
# 75%    7571.750000
# max    9955.000000

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
# Lastfour          244.0  4.981484e+03  2.956070e+03  1.100000e+01
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15
# ...

# %%
df.sort_values('tip',ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
#
# ...

# %%
df.sort_values(['tip','size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
# ...

# %%
df['total_bill'].max()
# Out:
# np.float64(50.81)

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Lastfour                        8236
# yelp                             $$$
# Quality                        Other
# Name: 170, dtype: object

# %%
df['total_bill'].min()
# Out:
# np.float64(3.07)

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
#  11  Lastfour          244 non-null    int64
#  12  yelp              244 non-null    object
#  13  Quality           244 non-null    object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 26.8+ KB

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 df.corr()
#
# File c:\Work\Python DataScience\.venv\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Work\Python DataScience\.venv\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].nunique()
# Out:
# 4

# %%
import pandas as pd
df=pd.read_csv(".//Data//tips.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['sex']=df['sex'].replace(['Female','Male'],['F','M'])

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
my_map={'Female':'F',"Male":'M'}
df['sex'].map(my_map)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df[df['total_bill'].between(10,12,inclusive='both')]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# 16        10.33  1.67  Female     No   Sun  Dinner     3              3.44
# 51        10.29  2.60  Female     No   Sun  Dinner     2              5.14
# 58        11.24  1.76    Male    Yes   Sat  Dinner     2              5.62
# 62        11.02  1.98    Male    Yes   Sat  Dinner     2              5.51
# 75        10.51  1.25    Male     No   Sat  Dinner     2              5.26
# 82        10.07  1.83  Female     No  Thur   Lunch     1             10.07
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2              5.68
# 117       10.65  1.50  Female     No  Thur   Lunch     2              5.32
# 120       11.69  2.31    Male     No  Thur   Lunch     2              5.84
# ...

# %% [markdown]
# ## Missing Values
#
# - remove
# - keep it
# - replace

# %%
import pandas as pd
df=pd.read_csv(".//Data//movie_scores.csv")
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df.isnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0       False      False  False  False            False             False
# 1        True       True   True   True             True              True
# 2       False      False  False  False             True              True
# 3       False      False  False  False            False             False
# 4       False      False  False  False            False             False

# %%
df.isna().sum()
# Out:
# first_name          1
# last_name           1
# age                 1
# sex                 1
# pre_movie_score     2
# post_movie_score    2
# dtype: int64

# %%
df[df['pre_movie_score'].notnull()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df[(df['pre_movie_score'].isna()) & (df['first_name'].notnull()) ]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 2       Hugh   Jackman  51.0   m              NaN               NaN

# %%
df.dropna(thresh=1)
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
help(df.fillna)
# Out:
# Help on method fillna in module pandas.core.generic:
#
# fillna(value: 'Hashable | Mapping | Series | DataFrame | None' = None, *, method: 'FillnaOptions | None' = None, axis: 'Axis | None' = None, inplace: 'bool_t' = False, limit: 'int | None' = None, downcast: 'dict | None | lib.NoDefault' = <no_default>) -> 'Self | None' method of pandas.core.frame.DataFrame instance
#     Fill NA/NaN values using the specified method.
#
#     Parameters
#     ----------
#     value : scalar, dict, Series, or DataFrame
#         Value to use to fill holes (e.g. 0), alternately a
#         dict/Series/DataFrame of values specifying which value to use for
#         each index (for a Series) or column (for a DataFrame).  Values not
#         in the dict/Series/DataFrame will not be filled. This value cannot
#         be a list.
#     method : {'backfill', 'bfill', 'ffill', None}, default None
#         Method to use for filling holes in reindexed Series:
#
# ...

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df['pre_movie_score']=df['pre_movie_score'].fillna(df['pre_movie_score'].mean())

# %%
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              7.0               NaN
# 2       Hugh   Jackman  51.0    m              7.0               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
import numpy as np
airtxt={'first':100,'business':np.nan,'economy':50,'economy_plus':899}
ser=pd.Series(airtxt)
ser
# Out:
# first           100.0
# business          NaN
# economy          50.0
# economy_plus    899.0
# dtype: float64

# %%
ser.interpolate()
# Out:
# first           100.0
# business         75.0
# economy          50.0
# economy_plus    899.0
# dtype: float64

# %% [markdown]
# ## Groupby()

# %%
import pandas as pd
df=pd.read_csv(".//Data/mpg.csv")
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df['model_year'].value_counts()
# Out:
# model_year
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 80    29
# 79    29
# 81    29
# 70    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: count, dtype: int64

# %%
numeric_df = df.select_dtypes(include='number')
result = numeric_df.groupby(df['model_year']).mean()

# %%
result
# Out:
#                   mpg  cylinders  displacement       weight  acceleration  \
# model_year
# 70          17.689655   6.758621    281.413793  3372.793103     12.948276
# 71          21.250000   5.571429    209.750000  2995.428571     15.142857
# 72          18.714286   5.821429    218.375000  3237.714286     15.125000
# 73          17.100000   6.375000    256.875000  3419.025000     14.312500
# 74          22.703704   5.259259    171.740741  2877.925926     16.203704
# 75          20.266667   5.600000    205.533333  3176.800000     16.050000
# 76          21.573529   5.647059    197.794118  3078.735294     15.941176
# 77          23.375000   5.464286    191.392857  2997.357143     15.435714
# 78          24.061111   5.361111    177.805556  2861.805556     15.805556
# 79          25.093103   5.827586    206.689655  3055.344828     15.813793
# 80          33.696552   4.137931    115.827586  2436.655172     16.934483
# ...

# %%
numeric_df.groupby(['model_year','cylinders']).mean()
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
numeric_df.groupby(['model_year','cylinders']).mean().columns
# Out:
# Index(['mpg', 'displacement', 'weight', 'acceleration', 'origin'], dtype='object')

# %%
numeric_df.groupby(['model_year','cylinders']).mean()['mpg']
# Out:
# model_year  cylinders
# 70          4            25.285714
#             6            20.500000
#             8            14.111111
# 71          4            27.461538
#             6            18.000000
#             8            13.428571
# 72          3            19.000000
#             4            23.428571
#             8            13.615385
# 73          3            18.000000
#             4            22.727273
#             6            19.000000
#             8            13.200000
# 74          4            27.800000
#             6            17.857143
#             8            14.200000
# 75          4            25.250000
#             6            17.583333
#             8            15.666667
# 76          4            26.766667
#             6            20.000000
#             8            14.666667
# 77          3            21.500000
#             4            29.107143
#             6            19.500000
#             8            16.000000
# ...

# %%
year_df=numeric_df.groupby(['model_year','cylinders']).mean()

# %%
year_df.index.levels
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])

# %%
year_df.loc[(80,)]
# Out:
#               mpg  displacement   weight  acceleration  origin
# cylinders
# 3          23.700          70.0  2420.00        12.500     3.0
# 4          34.612         111.0  2360.08        17.144     2.2
# 5          36.400         121.0  2950.00        19.900     2.0
# 6          25.900         196.5  3145.50        15.050     2.0

# %%
numeric_df.agg(['std','mean'])
# Out:
#             mpg  cylinders  displacement       weight  acceleration  \
# std    7.815984   1.701004    104.269838   846.841774      2.757689
# mean  23.514573   5.454774    193.425879  2970.424623     15.568090
#
#       model_year    origin
# std     3.697627  0.802055
# mean   76.010050  1.572864

# %%
df.agg({'mpg':['max','min'],'weight':['std','mean']})
# Out:
#        mpg       weight
# max   46.6          NaN
# min    9.0          NaN
# std    NaN   846.841774
# mean   NaN  2970.424623

# %% [markdown]
# ## Concatenation()

# %%
import pandas as pd
import numpy as np

c1={'A':['a0','a1','a2','a3'],'B':['b0','b1','b2','b3']}
c2={'C':['c0','c1','c2','c3'],'D':['d0','d1','d2','d3']}

one=pd.DataFrame(c1)
tw=pd.DataFrame(c2)

# %%
one
# Out:
#     A   B
# 0  a0  b0
# 1  a1  b1
# 2  a2  b2
# 3  a3  b3

# %%
tw
# Out:
#     C   D
# 0  c0  d0
# 1  c1  d1
# 2  c2  d2
# 3  c3  d3

# %%
pd.concat([one,tw],axis=1)
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3

# %%
pd.concat([one,tw],axis=0)
# Out:
#      A    B    C    D
# 0   a0   b0  NaN  NaN
# 1   a1   b1  NaN  NaN
# 2   a2   b2  NaN  NaN
# 3   a3   b3  NaN  NaN
# 0  NaN  NaN   c0   d0
# 1  NaN  NaN   c1   d1
# 2  NaN  NaN   c2   d2
# 3  NaN  NaN   c3   d3

# %%
tw.columns=one.columns
tw
# Out:
#     A   B
# 0  c0  d0
# 1  c1  d1
# 2  c2  d2
# 3  c3  d3

# %%
my_df=pd.concat([one,tw],axis=0)

# %%
my_df.reset_index(drop=True)
# Out:
#     A   B
# 0  a0  b0
# 1  a1  b1
# 2  a2  b2
# 3  a3  b3
# 4  c0  d0
# 5  c1  d1
# 6  c2  d2
# 7  c3  d3

# %% [markdown]
# ## Merge

# %%
reg={'reg_id':[1,2,3,4],'name':['Andew','bob','charlie','David']}
log={'log_id':[1,2,3,4],'name':['xavier','Andew','varun','bob']}

registration=pd.DataFrame(reg)
login=pd.DataFrame(log)

pd.merge(registration,login,how='inner',on='name')
# Out:
#    reg_id   name  log_id
# 0       1  Andew       2
# 1       2    bob       4

# %%
pd.merge(registration,login,how='left',on='name')
# Out:
#    reg_id     name  log_id
# 0       1    Andew     2.0
# 1       2      bob     4.0
# 2       3  charlie     NaN
# 3       4    David     NaN

# %%
pd.merge(login,registration,how='left',on='name')
# Out:
#    log_id    name  reg_id
# 0       1  xavier     NaN
# 1       2   Andew     1.0
# 2       3   varun     NaN
# 3       4     bob     2.0

# %%
pd.merge(registration,login,how='right',on='name')
# Out:
#    reg_id    name  log_id
# 0     NaN  xavier       1
# 1     1.0   Andew       2
# 2     NaN   varun       3
# 3     2.0     bob       4

# %%
registration
# Out:
#    reg_id     name
# 0       1    Andew
# 1       2      bob
# 2       3  charlie
# 3       4    David

# %%
merged_df=pd.merge(registration,login,how='outer',on='name')

merged_df['reg_id'] = merged_df['reg_id'].fillna(0).astype(int)
merged_df['log_id'] = merged_df['log_id'].fillna(0).astype(int)

# %%
merged_df
# Out:
#    reg_id     name  log_id
# 0       1    Andew       2
# 1       4    David       0
# 2       2      bob       4
# 3       3  charlie       0
# 4       0    varun       3
# 5       0   xavier       1

# %%
registration.columns=['reg_name','reg_id']

# %%
registration
# Out:
#    reg_name   reg_id
# 0         1    Andew
# 1         2      bob
# 2         3  charlie
# 3         4    David

# %% [markdown]
# ## Reading Excel

# %%
# pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_excel('.//Data/my_excel_file.xlsx',sheet_name='First_Sheet')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
wb=pd.ExcelFile(".//Data/my_excel_file.xlsx")
wb.sheet_names
# Out:
# ['First_Sheet']

# %%
df.to_excel("example.xlsx",sheet_name='Test')

# %% [markdown]
# ## Reading CSV

# %%
pwd
# Out:
# 'c:\\Work\\Python DataScience'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 2028-DBF2
#
#  Directory of c:\Work\Python DataScience
#
# 26-10-2024  08:44    <DIR>          .
# 13-10-2024  19:22    <DIR>          ..
# 13-10-2024  20:50                 5 .gitignore
# 13-10-2024  19:25    <DIR>          .venv
# 26-10-2024  08:41    <DIR>          Data
# 26-10-2024  08:44             5,059 example.xlsx
# 14-10-2024  12:15            24,119 Numpy.ipynb
# 26-10-2024  08:48           387,504 Pandas.ipynb
#                4 File(s)        416,687 bytes
#                4 Dir(s)  903,574,675,456 bytes free

# %% [markdown]
# ## Read SQL

# %%
# pip install sqlalchemy pyodbc
# Out:
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached greenlet-3.1.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.1 MB 2.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.1 MB 1.9 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.1 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.3 MB/s eta 0:00:00
# Using cached greenlet-3.1.1-cp312-cp312-win_amd64.whl (299 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

server = 'Neelakandan_OJ\SQLEXPRESS'   # e.g., 'MYPC\SQLEXPRESS'
database = 'SQL_Learning'
# data source=Neelakandan_OJ\SQLEXPRESS;initial catalog=master;trusted_connection=true
# Connection string using Windows Authentication
connection_string = f'mssql+pyodbc://@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes'

engine=create_engine(connection_string)

query="Select * from Sales"
df=pd.read_sql(query,engine)
engine.dispose()
df.head()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\S'
# <>:4: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\neela\AppData\Local\Temp\ipykernel_10232\4147170005.py:4: SyntaxWarning: invalid escape sequence '\S'
#   server = 'Neelakandan_OJ\SQLEXPRESS'   # e.g., 'MYPC\SQLEXPRESS'
#    ProductID    SaleDate  Quantity  TotalAmount  CustomerID  StoreID  \
# 0          1  2023-08-01        10        200.0         101        1
# 1          2  2023-08-01         5        150.0         102        1
# 2          1  2023-08-02         8        160.0         103        2
# 3          2  2023-08-02         7        210.0         104        2
# 4          1  2023-08-03         6        120.0         105        1
#
#    SalespersonID PaymentMethod
# 0            201   Credit Card
# 1            202          Cash
# 2            203   Credit Card
# 3            204          Cash
# 4            201          None

# %%
df.shape
# Out:
# (10, 8)

# %%
df
# Out:
#    ProductID    SaleDate  Quantity  TotalAmount  CustomerID  StoreID  \
# 0          1  2023-08-01        10        200.0         101        1
# 1          2  2023-08-01         5        150.0         102        1
# 2          1  2023-08-02         8        160.0         103        2
# 3          2  2023-08-02         7        210.0         104        2
# 4          1  2023-08-03         6        120.0         105        1
# 5          3  2023-08-04        12        300.0         106        3
# 6          1  2023-08-04         5        100.0         107        3
# 7          2  2023-08-05         9        270.0         108        1
# 8          3  2023-08-05        15        375.0         109        3
# 9          1  2023-08-06         7        140.0         110        2
#
#    SalespersonID PaymentMethod
# 0            201   Credit Card
# 1            202          Cash
# 2            203   Credit Card
# 3            204          Cash
# 4            201          None
# ...

# %%
df.to_sql(name='NewSales',con=engine)
# Out:
# 10

# %% [markdown]
# ## Read HTML

# %%
# pip install lxml
# Out:
# ...
#   Using cached lxml-5.3.0-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Using cached lxml-5.3.0-cp312-cp312-win_amd64.whl (3.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
url="https://en.wikipedia.org/wiki/World_population"
tabes=pd.read_html(url)

# %%
len(tabes)
# Out:
# 31

# %%
df=tabes[5]

# %%
df.to_sql(name='Top10Pop',con=engine)
# Out:
# 10

# %%
df.to_html('top10.html',index=False)

# %% [markdown]
# ##  Text Methods

# %%
import pandas as pd
import numpy as np

email='jose@email.com'

# %%
email.split('@')
# Out:
# ['jose', 'email.com']

# %%
email.isdigit()
# Out:
# False

# %%
names=pd.Series(['andrew','bobo','clarie','david','joe'])
names
# Out:
# 0    andrew
# 1      bobo
# 2    clarie
# 3     david
# 4       joe
# dtype: object

# %%
names.str.upper()
# Out:
# 0    ANDREW
# 1      BOBO
# 2    CLARIE
# 3     DAVID
# 4       JOE
# dtype: object

# %%
names.str.isdigit()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
tech_finane=['Goog,Apple,AMZN','JPM,BAC,GS']
len(tech_finane)
# Out:
# 2

# %%
ticker=pd.Series(tech_finane)

# %%
ticker
# Out:
# 0    Goog,Apple,AMZN
# 1         JPM,BAC,GS
# dtype: object

# %%
ticker.str.split(',')[0][0]
# Out:
# 'Goog'

# %%
ticker.str.split(',',expand=True)
# Out:
#       0      1     2
# 0  Goog  Apple  AMZN
# 1   JPM    BAC    GS

# %%
messy_names=pd.Series(['andrew ','bbo;bo','   clarie  '])
messy_names
# Out:
# 0        andrew
# 1         bbo;bo
# 2       clarie
# dtype: object

# %%
messy_names=messy_names.replace(';','').str.strip().str.capitalize()

# %%
messy_names
# Out:
# 0    Andrew
# 1     Bbobo
# 2    Clarie
# dtype: object

# %%
def cleanup(name):
    name=name.replace(';','')
    name=name.capitalize()
    name=name.strip()
    return name

# %%
messy_names.apply(cleanup)
# Out:
# 0    Andrew
# 1     Bbobo
# 2    Clarie
# dtype: object

# %% [markdown]
# ## Datetime

# %%
from datetime import datetime
